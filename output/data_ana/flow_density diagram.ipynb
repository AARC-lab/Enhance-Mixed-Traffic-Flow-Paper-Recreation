# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the uploaded CSV file
file_path = "/home/ruby/Nazmus Shakib/AARC Lab/Paper Recreation: Enhance Mix Traffic Flow/output/data/base_info_data/new_baseline__1800_mpr_0_flow_36_8_time_1800_ramp.csv"
df = pd.read_csv(file_path)

# Display the first few rows to understand the structure
df.head()
# Out:
# /tmp/ipykernel_3711730/1086843617.py:3: DtypeWarning: Columns (0,1,2,7,8,9,21,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#    left_lane vehicle_id_left vehicle_type_left  speed_left      acc_left  \
# 0  left_lane    flow_HDV_0.0           HDV_ori   32.393600  0.000000e+00
# 1  left_lane    flow_HDV_0.0           HDV_ori   32.393600 -5.222418e-09
# 2  left_lane    flow_HDV_0.1           HDV_ori   27.281684 -9.112514e-01
# 3  left_lane    flow_HDV_0.0           HDV_ori   32.393600 -4.413678e-09
# 4  left_lane    flow_HDV_0.1           HDV_ori   26.879938 -2.010748e-01
#
#     pos_left  time_stamp_left  middle_lane vehicle_id_middle  \
# 0   5.100000              0.0  middle_lane      flow_HDV_0.4
# 1  40.732960              1.0  middle_lane      flow_HDV_0.4
# 2   7.828168              1.0  middle_lane      flow_HDV_0.5
# 3  69.887200              2.0  middle_lane      flow_HDV_0.4
# ...

# %%
# Road and simulation details
road_length_km = 3.25
simulation_time_hours = 1800 / 3600  # convert seconds to hours

# Function to calculate density and flow correctly per lane
def compute_density_flow(df, vehicle_col, mpr=0, lane="left"):
    vehicles = df[vehicle_col].dropna().unique()
    vehicle_count = len(vehicles)
    density = vehicle_count / road_length_km  # veh/km
    flow = vehicle_count / simulation_time_hours  # veh/h
    print(f"MPR: {mpr}, Lane: {lane}, Vehicle count: {vehicle_count}")
    return vehicle_count

# Calculate for each lane
mpr = 100
v_count_left_100 = compute_density_flow(df, 'vehicle_id_left', mpr, "left")
v_count_mid_100 = compute_density_flow(df, 'vehicle_id_middle', mpr, "mid")
v_count_right_100 = compute_density_flow(df, 'vehicle_id_right', mpr, "right")
# Out:
# MPR: 100, Lane: left, Vehicle count: 600
# MPR: 100, Lane: mid, Vehicle count: 736
# MPR: 100, Lane: right, Vehicle count: 863
